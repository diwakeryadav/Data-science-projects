# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

# %matplotlib inline

# %% [markdown]
# ### Simple breakdown of the features and its type
# 1. Rank                           - The overall rank associated to the country.             - DATATYPE(INT64)
# 1. Country                        - The country which we are talking about.                 - DATATYPE(OBJECT)
# 2. Cost of Living Index           - Denoting the cost of living in that country             - DATATYPE(FLOAT)
# 3. Rent Index                     - Denoting the cost of rent in the country                - DATATYPE(FLOAT)
# 4. Cost of Living plus Rent Index - Denoting the cost as well as the rent index             - DATATYPE(FLOAT)
# 5. Groceries index                - Denoting the price of groceries in the specific country - DATATYPE(FLOAT)
# 6. Restaurant Price index         - Denoting the cost of going to a restaurant              - DATATYPE(FLOAT)

# %%
df=pd.read_csv('../dataset/Cost_of_Living_Index_by_Country_2024.csv')

# %%
df
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Switzerland                 101.1        46.5
# 1       2      Bahamas                  85.0        36.7
# 2       3      Iceland                  83.0        39.2
# 3       4    Singapore                  76.7        67.2
# 4       5     Barbados                  76.6        19.0
# ..    ...          ...                   ...         ...
# 116   117   Bangladesh                  22.5         2.4
# 117   118        India                  21.2         5.6
# 118   119        Egypt                  21.0         3.7
# 119   120        Libya                  20.4         4.3
# 120   121     Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                              74.9            109.1                    97.0
# 1                              61.8             81.6                    83.3
# ...

# %%
df.isnull().sum()
# Out:
# Rank                              0
# Country                           0
# Cost of Living Index              0
# Rent Index                        0
# Cost of Living Plus Rent Index    0
# Groceries Index                   0
# Restaurant Price Index            0
# Local Purchasing Power Index      0
# dtype: int64

# %%
df.describe()
# Out:
#              Rank  Cost of Living Index  Rent Index  \
# count  121.000000            121.000000  121.000000
# mean    61.000000             43.555372   16.052893
# std     35.073732             16.147574   11.412267
# min      1.000000             18.800000    2.400000
# 25%     31.000000             30.200000    8.500000
# 50%     61.000000             39.500000   12.400000
# 75%     91.000000             52.800000   20.100000
# max    121.000000            101.100000   67.200000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                      121.000000       121.000000
# mean                        30.357851        44.228926
# std                         13.263721        17.055109
# min                         11.100000        17.500000
# 25%                         19.800000        31.600000
# 50%                         27.000000        40.500000
# 75%                         37.000000        53.700000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            121 non-null    int64
#  1   Country                         121 non-null    object
#  2   Cost of Living Index            121 non-null    float64
#  3   Rent Index                      121 non-null    float64
#  4   Cost of Living Plus Rent Index  121 non-null    float64
#  5   Groceries Index                 121 non-null    float64
#  6   Restaurant Price Index          121 non-null    float64
#  7   Local Purchasing Power Index    121 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.7+ KB

# %%
plt.figure(figsize=(15, 10))

plt.subplot(1, 3, 1)
sns.scatterplot(data=df, x='Cost of Living Plus Rent Index', y='Local Purchasing Power Index')
plt.title('Cost of Living Plus Rent Index vs Purchasing Power Index')

plt.subplot(1, 3, 2)
sns.scatterplot(data=df, x='Restaurant Price Index', y='Local Purchasing Power Index')
plt.title('Restaurant Price Index vs Purchasing Power Index')

plt.subplot(1, 3, 3)
sns.scatterplot(data=df, x='Groceries Index', y='Local Purchasing Power Index')
plt.title('Groceries Index vsPurchasing Power Index')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df, x='Country', y='Local Purchasing Power Index',hue='Local Purchasing Power Index')
plt.title('Country vs Purchasing Power Index')
# Out:
# Text(0.5, 1.0, 'Country vs Purchasing Power Index')

# %%
top_5_largest = df.nlargest(10, 'Local Purchasing Power Index')

# %%
top_5_largest
# Out:
#     Rank               Country  Cost of Living Index  Rent Index  \
# 19    20            Luxembourg                  62.4        40.5
# 51    52                Kuwait                  42.1        22.6
# 36    37                 Qatar                  51.3        36.1
# 0      1           Switzerland                 101.1        46.5
# 8      9         United States                  70.4        41.7
# 50    51                  Oman                  42.4        12.2
# 47    48          Saudi Arabia                  45.3        11.3
# 26    27  United Arab Emirates                  55.8        41.3
# 9     10             Australia                  70.2        33.4
# 6      7               Denmark                  72.3        26.4
#
#     Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 19                            51.9             64.1                    68.7
# 51                            32.7             34.5                    36.4
# ...

# %%
plt.figure(figsize=(15, 10))
sns.barplot(data=top_5_largest, x=top_5_largest['Country'], y=top_5_largest['Cost of Living Index'], palette='viridis')
plt.xlabel('Country')
# Out:
# C:\Users\91858\AppData\Local\Temp\ipykernel_6444\2155271478.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_largest, x=top_5_largest['Country'], y=top_5_largest['Cost of Living Index'], palette='viridis')
# Text(0.5, 0, 'Country')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Cost of Living Index', y='Groceries Index', data=top_5_largest, hue='Country', palette='tab10', s=100)
plt.title('Cost of Living Index vs. Groceries Index')
plt.xlabel('Cost of Living Index')
plt.ylabel('Groceries Index')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
top_5_lowest = df.nsmallest(10,'Local Purchasing Power Index')

# %%
top_5_lowest
# Out:
#      Rank     Country  Cost of Living Index  Rent Index  \
# 42     43        Cuba                  46.7        11.8
# 114   115       Syria                  24.0         3.7
# 71     72    Cameroon                  37.3        16.9
# 85     86     Nigeria                  31.4        22.1
# 64     65   Venezuela                  38.3         5.8
# 113   114  Madagascar                  24.5         7.8
# 76     77   Sri Lanka                  34.6         5.6
# 99    100      Uganda                  29.1         7.7
# 89     90       Ghana                  30.9        10.2
# 118   119       Egypt                  21.0         3.7
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 42                             29.9             43.0                    26.0
# 114                            14.2             24.5                    15.3
# 71                             27.5             34.6                    35.3
# ...

# %%
plt.figure(figsize=(15, 10))
sns.barplot(data=top_5_lowest, x=top_5_lowest['Country'], y=top_5_lowest['Cost of Living Index'], palette='viridis')
plt.xlabel('Country')
# Out:
# C:\Users\91858\AppData\Local\Temp\ipykernel_6444\2196141476.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_lowest, x=top_5_lowest['Country'], y=top_5_lowest['Cost of Living Index'], palette='viridis')
# Text(0.5, 0, 'Country')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Cost of Living Index', y='Groceries Index', data=top_5_lowest, hue='Country', palette='tab10', s=100)
plt.title('Cost of Living Index vs. Groceries Index')
plt.xlabel('Cost of Living Index')
plt.ylabel('Groceries Index')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df_corr=df.drop(columns='Country')

# %%
corr_matrix=df_corr.corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
def drop_highly_correlated(df_corr, threshold=0.8):
    correlation_matrix = df_corr.corr()
    to_drop = set()
    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > threshold:
                colname = correlation_matrix.columns[i]
                to_drop.add(colname)
    return to_drop

# Drop variables
columns_to_drop = drop_highly_correlated(df_corr)
df_reduced = df_corr.drop(columns=columns_to_drop)

print("Columns to drop:", columns_to_drop)
# Out:
# Columns to drop: {'Cost of Living Plus Rent Index', 'Restaurant Price Index', 'Rent Index', 'Cost of Living Index', 'Groceries Index'}

# %% [markdown]
# # Applying linear regression assuming we want to predict the cost of living

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df[['Cost of Living Plus Rent Index','Local Purchasing Power Index']]
y = df['Cost of Living Index']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=50)

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
print(f'Mean Sqaured Error:{mse}')
print(f'r2 score: {r2}')
# Out:
# Mean Sqaured Error:21.309561315347274
# r2 score: 0.9092575355835072

# %%
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 4.616228039790417

# %%
from sklearn.linear_model import ElasticNet
model = ElasticNet(alpha=0.1, l1_ratio=0.5)  # alpha is the regularization parameter, l1_ratio controls the mix of L1 and L2
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error: 16.94032415173743
# R^2 Score: 0.9278630498866355

# %%
plt.scatter(y_test, y_pred, color='blue', label='Predicted values')
plt.scatter(y_test, y_test, color='red', label='Actual values')


plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Actual vs Predicted Values')

plt.legend()
